# %%
# prompt: mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="v9V9iRkuJoRn7dK8DtmV")
project = rf.workspace("kavitha-lakshmi-i0dls").project("dataset-6-cell-tower")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.0 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Dataset-6(cell-tower)-1 in yolov8:: 100%|██████████| 5256/5256 [00:01<00:00, 2843.81it/s]

# %%
# prompt: where this dataset is stored in google drive

print(dataset.location)
# Out:
# /content/Dataset-6(cell-tower)-1

# %%
ROOT_DIR = '/content/Dataset-6(cell-tower)-1'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=30)  # train the model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# AttributeError: '_PyDrive2ImportHook' object has no attribute 'find_spec'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.10/importlib/_bootstrap.py in _object_name(obj)
#
# AttributeError: '_PyDrive2ImportHook' object has no attribute '__qualname__'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6918b38503a7> in <cell line: 3>()
#       1 import os
#       2
# ----> 3 from ultralytics import YOLO
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py in <module>
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !export LC_ALL=C.UTF-8
# !export LANG=C.UTF-8
# !scp -r /content/runs '/content/drive/MyDrive/Tower_Program'
# Out:
# cp: cannot stat '/content/runs': No such file or directory

# %%
# !pip uninstall torch torchvision -y
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# Found existing installation: torch 2.3.1+cu121
# Uninstalling torch-2.3.1+cu121:
#   Successfully uninstalled torch-2.3.1+cu121
# Found existing installation: torchvision 0.18.1+cu121
# Uninstalling torchvision-0.18.1+cu121:
#   Successfully uninstalled torchvision-0.18.1+cu121
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.7/857.7 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 101.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 102.8 MB/s eta 0:00:00
# ...

# %%
# prompt: I have trained the yolo v8 model for training joints and side in mobile tower now I want to test the model on our own image sources. we will load the weights of pre trained model. then also display the predicted image with object detecton bounding boxes along with confidence score. write a complete code

from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load a model
model = YOLO('/content/drive/MyDrive/Tower_Program/runs/detect/train3/weights/best.pt')  # load a pretrained model (recommended for training)

# predict on an image
img_path = '/content/drive/MyDrive/Tower_Program/DJI_20210924143625_0013_SUPR_JPG_jpg.rf.005fc709050432ed9e7874e76167d9fc.jpg'
results = model(img_path)

# Display the predicted image
result = results[0]
annotated_frame = result.plot()
cv2_imshow(annotated_frame)
# Out:
# image 1/1 /content/drive/MyDrive/Tower_Program/DJI_20210924143625_0013_SUPR_JPG_jpg.rf.005fc709050432ed9e7874e76167d9fc.jpg: 640x640 2 joints, 2 sides, 7.5ms
# Speed: 6.4ms preprocess, 7.5ms inference, 96.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
